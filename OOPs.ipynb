# %% [markdown]
# 1.What is Object-Oriented Programming (OOP)?
# --
# Object-Oriented Programming (OOP) is a programming paradigm based on the concept of "objects," which can contain both data (in the form of fields, often known as attributes or properties) and code (in the form of methods, which are functions that operate on the data).
#
# 2.What is a class in OOP?
# --
# In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines the structure and behavior that the objects created from it will have. A class specifies the attributes (data or properties) and methods (functions or behaviors) that are common to all objects of that type.
#
# 3.What is an object in OOP?
# --
# In Object-Oriented Programming (OOP), an object is an instance of a class. It is a self-contained unit that contains both data (attributes) and functions (methods) that can operate on the data. Objects are created from classes, and they represent real-world entities or concepts within the program. Each object has its own unique state and can perform actions defined by its class.
#
# 4.What is the difference between abstraction and encapsulation?
# --
# Abstraction and Encapsulation are both fundamental concepts in Object-Oriented Programming (OOP), but they serve different purposes.
#
# Abstraction is the process of hiding the complex implementation details and showing only the essential features of an object. It allows you to focus on what an object does, rather than how it does it.
#
# Encapsulation is the concept of bundling the data (attributes) and the methods that operate on the data into a single unit, which is the object. It also involves restricting access to some of the object's components by making some attributes or methods private (hidden from outside access), which is done to protect the integrity of the data and avoid unintended interference.
#
# 5.What are dunder methods in Python?
# --
# Dunder methods (also known as magic methods or special methods) in Python are methods that have a double underscore before and after their name. The term "dunder" comes from the abbreviation of "double underscore" (e.g., __init__, __str__, __add__).
#
# These methods are special because they are automatically invoked by Python's interpreter when certain operations or actions are performed on objects. They are typically used to customize the behavior of objects in ways that Python’s built-in operations (like addition, string representation, etc.) work with.
#
#
# 6.Explain the concept of inheritance in OOP.
# --
# Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows one class (called a child or subclass) to inherit the properties and behaviors (attributes and methods) of another class (called a parent or superclass). This concept helps promote code reuse, extensibility, and maintainability by allowing new classes to use, extend, or modify the behavior of existing classes.
#
# Key Concepts in Inheritance:
# Parent Class (Superclass): The class that provides the properties and methods to be inherited. It is also called the base class or parent class.
#
# Child Class (Subclass): The class that inherits the properties and methods from the parent class. It is also called the derived class or subclass. The subclass can add new properties and methods or override the inherited methods.
#
# Method Overriding: The child class can modify (or override) a method inherited from the parent class to provide a more specific implementation.
#
# Access to Parent Methods and Attributes: The child class has access to all the public and protected methods and attributes of the parent class (unless explicitly hidden using private access modifiers).
#
# 7.What is polymorphism in OOP?
# --
# Polymorphism is a core concept in Object-Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass. The term "polymorphism" comes from the Greek words "poly" (meaning many) and "morph" (meaning form or shape), so it essentially means many forms.
#
# In OOP, polymorphism allows different classes to share the same interface or method names, but they can have different implementations (behavior). This enables flexibility and the ability to interact with different types of objects in a consistent manner.
#
# 8.How is encapsulation achieved in Python?
# --
# Encapsulation is one of the key principles of Object-Oriented Programming (OOP), and it refers to the concept of bundling the data (attributes) and the methods (functions) that operate on that data within a single unit, or class. Encapsulation also helps restrict direct access to some of an object's attributes or methods, which is known as data hiding.
#
# In Python, encapsulation is achieved by:
#
# Using classes to bundle data and methods together.
# Using access modifiers to control the visibility and accessibility of class attributes and methods.
#
# 9.What is a constructor in Python?
# --
# A constructor in Python is a special method used to initialize objects when they are created. It is a part of the object initialization process, ensuring that the object's attributes (data) are set to their initial values when an instance of a class is created.
#
# In Python, the constructor is defined by the method __init__, which stands for "initialization."
#
# 10.What are class and static methods in Python?
# --
# class methods and static methods are two types of methods that are different from instance methods, which are the most common type of methods tied to an object instance. Both class and static methods are defined within a class, but they have distinct uses and behaviors. Let’s explore each in detail.
#
# A class method is a method that is bound to the class rather than the instance of the class. It can access and modify class-level attributes, and it takes cls (which refers to the class itself) as the first parameter, rather than self (which refers to an instance of the class).
#
# A static method is a method that does not depend on the class or instance to work. It does not take self or cls as its first argument, meaning it cannot modify or access instance or class attributes. Static methods are defined using the @staticmethod decorator.
#
# 11.What is method overloading in Python?
# --
# Method overloading in Python refers to the ability to define multiple methods with the same name but with different parameters. However, Python does not support traditional method overloading as seen in other languages like Java or C++, where multiple methods can exist with the same name but different parameter lists (e.g., one method with one parameter, another with two parameters, etc.).
#  Python doesn't support method overloading in the traditional sense, you can achieve similar behavior by using default arguments or variable-length arguments.
#
#  12.What is method overriding in OOP?
# --
# Method overriding in Object-Oriented Programming (OOP) refers to the ability of a subclass (child class) to provide a specific implementation of a method that is already defined in its parent class (superclass). This means that the method in the child class has the same name, same parameters, and same signature as the method in the parent class, but the behavior of the method is customized or altered in the child class.
#
# 13.What is a property decorator in Python?
# --
# In Python, the @property decorator is used to define getter methods that allow you to access an instance's attribute like a regular attribute, but with the added functionality of a method. It allows you to encapsulate data and provide additional behavior when retrieving the value of an attribute.
#
# The @property decorator allows you to define methods that behave like attributes, providing a way to access data with custom logic.
# It encapsulates attributes and enables validation or computation before accessing or modifying them.
# It allows getter methods, setter methods, and computed properties (that act like attributes but are calculated on the fly).
# Using @property, you can create cleaner, more maintainable code while exposing simple interfaces for interacting with complex data.
#
# 14.Why is polymorphism important in OOP?
# --
# Polymorphism is one of the fundamental concepts in Object-Oriented Programming (OOP), and it plays a crucial role in making code more flexible, reusable, and maintainable.
# In simple terms, polymorphism allows objects of different classes to be treated as objects of a common superclass. More specifically, it allows the same method or operation to behave differently depending on the type of object that it is acting on.
#
# Polymorphism is important because it enables:
#
# Code reusability and reduces redundancy.
# Flexibility to handle new types without changing existing code.
# Improved maintainability through a cleaner, more extensible design.
# Dynamic behavior based on object types, enabling more sophisticated and generalized code.
#
# 15.What is an abstract class in Python?
# --
# An abstract class in Python is a class that cannot be instantiated on its own and is meant to serve as a blueprint for other classes. It allows you to define methods that must be implemented by subclasses, but it does not provide full implementations of those methods. Instead, it declares the methods that must be overridden in any subclass.
#
# 16.What are the advantages of OOP?
# --
# OOP provides several key advantages that lead to better software design, maintainability, scalability, and security. By promoting modularity, code reuse, and flexibility, OOP makes it easier to build, extend, and maintain complex systems. It also supports principles like encapsulation and abstraction, which help in organizing and protecting data, while polymorphism ensures that objects of different types can be treated uniformly.
#
# These advantages make OOP particularly well-suited for large-scale applications, as well as for projects that require frequent updates and maintenance.
#
# 17.What is the difference between a class variable and an instance variable?
# --
# In Object-Oriented Programming (OOP), class variables and instance variables are two types of variables that are used to store data in a class. They differ in their scope, behavior, and how they are shared across instances of a class.
#
# Class Variable:
# A class variable is shared among all instances of the class.
# It is defined inside the class but outside any instance methods (i.e., methods that belong to objects of the class).
# The value of a class variable is the same for all instances of the class, meaning that it is shared between all objects of that class.
# It can be accessed by both the class itself and all instances of the class.
#
# Instance Variable:
# An instance variable is a variable that is tied to a specific instance (or object) of the class.
# It is defined inside the constructor (__init__ method) or inside any instance method, using the self keyword.
# Each instance of the class can have its own unique value for the instance variables, meaning that changes to an instance variable only affect that particular object, not other instances.
#
# 18.What is multiple inheritance in Python?
# --
# Multiple inheritance in Python is a feature that allows a class to inherit from more than one parent class. This means that a single class can inherit attributes and methods from multiple base classes, which can be useful when you want to combine behaviors from different classes into a new class.
#
# Multiple inheritance allows a class to inherit from more than one parent class, enabling it to combine features from different classes.
# It provides flexibility, but it can also introduce complexity, especially when dealing with method resolution order and potential conflicts between parent classes.
# Python uses the MRO (Method Resolution Order) to determine which method to call when there are conflicts, ensuring that the correct method is called based on the inheritance hierarchy.
#
# 19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# --
# In Python, the __str__ and __repr__ methods are special (also called dunder methods, short for "double underscore") that are used to define how an object is represented as a string. While both methods are used to represent objects as strings, they have distinct purposes and are intended for different scenarios.
#
#  __str__ Method:
# The __str__ method is used to define the string representation of an object for end-users (or when you use print() on the object). The output of this method is meant to be human-readable.
#
# Purpose: To provide a readable, user-friendly string representation of the object.
# This method is called by the str() function and the print() function.
# If __str__ is not defined, Python will use the default implementation (from the object class), which looks like <__main__.ClassName object at memory_address>.
#
# __repr__ Method:
# The __repr__ method is used to define the official string representation of an object. The goal is to provide a more detailed or unambiguous representation that can ideally be used to recreate the object or provide information that is useful for debugging.
#
# Purpose: To provide a formal, unambiguous string representation of the object. The output is typically used for debugging and logging.
# This method is called by the repr() function and is often used in the Python shell to display objects.
# If __repr__ is not defined, Python will use the default implementation from the object class, which looks like <__main__.ClassName object at memory_address>.
#
# 20.What is the significance of the ‘super()’ function in Python?
# --
# The super() function in Python is a built-in function used to call methods from a parent (or superclass) within a child (or subclass). It provides a way for the child class to invoke the methods or constructors of its parent class without explicitly referring to the parent class by name. This is particularly useful in the context of inheritance, especially when dealing with multiple inheritance.
#
# The super() function is a powerful feature of Python’s object-oriented programming that allows a child class to invoke methods from its parent class in a clean and maintainable way. It simplifies code reuse, supports multiple inheritance, and helps in maintaining proper method resolution order.
#
# 21.What is the significance of the __del__ method in Python?
# --
# The __del__ method in Python is a destructor method that is called when an object is about to be destroyed or garbage collected. It allows you to define cleanup behavior for an object before it is removed from memory, such as closing files, releasing network resources, or performing other necessary resource management tasks.
#
# Purpose and Use of __del__:
# The __del__ method is primarily used for cleaning up resources that the object might have acquired during its lifetime (e.g., closing files, releasing network connections, etc.).
# It is automatically invoked when the object is no longer in use, and Python’s garbage collector decides that the object is eligible for deletion.
#
#            class MyClass:
#                def __del__(self):
#                    # Cleanup code (e.g., closing files, releasing resources)
#                    print(f"{self} is being destroyed.")
#
#
#
# 22.What is the difference between @staticmethod and @classmethod in Python?
# --
# In Python, both @staticmethod and @classmethod are used to define methods that are associated with a class, rather than instances of the class.
#
# @staticmethod:
#
# Use when you want to define a method that doesn't depend on the class or instance but is still related to the class logically.
# It is typically used for utility functions that perform operations that don't rely on the class state.
#
# @classmethod:
#
# Use when you need to define a method that operates on the class and has access to class-level data (but not instance data).
# Class methods are often used for factory methods, which are used to create objects in specific ways, or for methods that modify class-level attributes.
#
# 23.How does polymorphism work in Python with inheritance?
# --
# In object-oriented programming (OOP), inheritance allows a child class to inherit methods and attributes from a parent class. When polymorphism is introduced, the child class can override methods from the parent class, and depending on the instance type, the appropriate method will be called.
#
# In Python, polymorphism is often implemented through method overriding. Even though different objects (instances) might call the same method, they can behave differently because the method can be overridden in the child class.
#
# 24.What is method chaining in Python OOP?
# --
# Method chaining in Python refers to the practice of calling multiple methods on the same object in a single line of code, one after the other. This is possible because each method returns the object itself (or another object), allowing subsequent method calls to be made on that returned object.
#
# Method chaining is a powerful technique in Python that enables multiple method calls to be linked together in a single line of code. By returning self from each method, it makes your code more concise, readable, and efficient. It is commonly used in classes that perform actions or manipulations on an object, such as builders, calculators, and configuration managers.
#
# 25.What is the purpose of the _ _ call _ _ method in Python?
# --
# The __call__ method in Python is a special method that allows an instance of a class to be called like a function. When you implement the __call__ method in a class, it enables objects of that class to behave like functions, meaning you can invoke the object using parentheses (()) and pass arguments to it, just like a function call.
#
# Purpose of the __ call __ Method:
#
# The primary purpose of the __call__ method is to allow instances of a class to be invoked as if they were functions. This can be useful in several scenarios, such as:
#
# Creating Callable Objects: Sometimes, it's beneficial to design an object that can behave like a function but still retain its state and other object-oriented features.
#
# Encapsulating Functionality: You might want to create an object that encapsulates some complex functionality, but still want it to be used in a functional way (i.e., called like a regular function).
#
# Creating Decorators: The __call__ method is commonly used in creating Python decorators. Decorators often use classes to encapsulate the decorator logic, and the __call__ method allows them to be used like a function.

# %%
#  1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

animal = Animal()
dog = Dog()

animal.speak()
dog.speak()

# %%
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of the circle: {circle.area()}")
print(f"Area of the rectangle: {rectangle.area()}")

# %%
#  3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, type):
        self.type = type

    def display_type(self):
        print(f"This is a {self.type}.")

class Car(Vehicle):
    def __init__(self, type, model):
        super().__init__(type)
        self.model = model

    def display_model(self):
        print(f"This car is a {self.model}.")

class ElectricCar(Car):
    def __init__(self, type, model, battery_capacity):
        super().__init__(type, model)
        self.battery_capacity = battery_capacity

    def display_battery(self):
        print(f"This electric car has a battery capacity of {self.battery_capacity} kWh.")

vehicle = Vehicle("vehicle")
car = Car("car", "Sedan")
electric_car = ElectricCar("electric car", "Tesla Model S", 100)

vehicle.display_type()
car.display_type()
car.display_model()
electric_car.display_type()
electric_car.display_model()
electric_car.display_battery()

# %%
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
        print("This bird can fly.")

class Sparrow(Bird):
    def fly(self):
        print("The sparrow is flying.")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly.")

sparrow = Sparrow()
penguin = Penguin()

sparrow.fly()
penguin.fly()
# Out:
# The sparrow is flying.
# Penguins cannot fly.

# %%
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ${amount}")
        elif amount > self.__balance:
            print("Insufficient balance!")
        else:
            print("Withdrawal amount must be positive.")

    def check_balance(self):
        print(f"Current balance: ${self.__balance}")

account = BankAccount(1000)

account.check_balance()
account.deposit(500)
account.check_balance()
account.withdraw(200)
account.check_balance()
account.withdraw(1500)

# %%
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing a generic instrument.")

class Guitar(Instrument):
    def play(self):
        print("Playing the guitar.")

class Piano(Instrument):
    def play(self):
        print("Playing the piano.")

def start_playing(instrument):
    instrument.play()

guitar = Guitar()
piano = Piano()

start_playing(guitar)
start_playing(piano)

# %%
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

sum_result = MathOperations.add_numbers(10, 5)
print(f"Sum: {sum_result}")

difference_result = MathOperations.subtract_numbers(10, 5)
print(f"Difference: {difference_result}")

# %%
# 8. Implement a class Person with a class method to count the total number of persons created.

class Person:
    total_persons = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person.total_persons += 1

    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

person1 = Person("Alice", 30)
person2 = Person("Bob", 25)
person3 = Person("Charlie", 35)

total_persons_created = Person.get_total_persons()
print(f"Total persons created: {total_persons_created}")  # Output: Total persons created: 3

# %%
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

fraction1 = Fraction(3, 4)
fraction2 = Fraction(5, 8)

print(fraction1)
print(fraction2)

# %%
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Operands must be instances of Vector")

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(1, 2)
v2 = Vector(3, 4)

v3 = v1 + v2

print(f"v1: {v1}")
print(f"v2: {v2}")
print(f"v3: {v3}")

# %%
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("Alice", 30)
person1.greet()
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

student1 = Student("Alice", [85, 90, 78, 92, 88])
print(f"{student1.name}'s average grade is {student1.average_grade():.2f}")

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def __init__(self, length=1, width=1):
        """Initialize the rectangle with default dimensions of 1x1."""
        self.length = length
        self.width = width

    def set_dimensions(self, length, width):
        """Set the dimensions of the rectangle."""
        self.length = length
        self.width = width

    def area(self):
        """Calculate and return the area of the rectangle."""
        return self.length * self.width

rect = Rectangle()
print(f"Default area: {rect.area()}")

rect.set_dimensions(5, 3)
print(f"Area after setting dimensions: {rect.area()}")

# %%
#  14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        """Calculate and return the salary based on hours worked and hourly rate."""
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        """Calculate and return the salary including the bonus."""
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

employee = Employee("Alice", 160, 25)
print(f"{employee.name}'s salary: ${employee.calculate_salary()}")

manager = Manager("Bob", 160, 30, 500)
print(f"{manager.name}'s salary: ${manager.calculate_salary()}")

# %%
#  15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        """Initialize the product with name, price, and quantity."""
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        """Calculate and return the total price of the product."""
        return self.price * self.quantity


product = Product("Laptop", 1000, 5)
print(f"Total price for {product.quantity} {product.name}s: ${product.total_price()}")

# %%
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        """Abstract method to be implemented by subclasses."""
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

cow = Cow()
print(f"Cow sound: {cow.sound()}")

sheep = Sheep()
print(f"Sheep sound: {sheep.sound()}")

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        """Initialize the book with title, author, and year of publication."""
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        """Return a formatted string with the book's details."""
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())
# Out:
# '1984' by George Orwell, published in 1949

# %%
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        """Initialize the house with address and price."""
        self.address = address
        self.price = price

    def get_house_info(self):
        """Return a formatted string with the house's details."""
        return f"Address: {self.address}, Price: ${self.price}"

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        """Initialize the mansion with address, price, and number of rooms."""
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_mansion_info(self):
        """Return a formatted string with the mansion's details."""
        return f"{self.get_house_info()}, Number of rooms: {self.number_of_rooms}"

house = House("123 Main St", 250000)
print(house.get_house_info())

mansion = Mansion("456 Luxury Ave", 5000000, 10)
print(mansion.get_mansion_info())
# Out:
# Address: 123 Main St, Price: $250000
# Address: 456 Luxury Ave, Price: $5000000, Number of rooms: 10
